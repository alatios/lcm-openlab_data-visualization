# %% [markdown]
# # Data visualization in Python

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
import matplotlib

# %%
font = {
    'family': 'serif',
    'serif': ['cmr10'],
    'size': 26
}

#matplotlib.rc('font', **font)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#plt.style.use('ggplot')

# %%
df = pd.read_hdf('~/lhcb_data/data.h5', key='LHCbMC_Lb')

# %%
df
# Out:
#          Lb_ENDVERTEX_X  Lb_ENDVERTEX_Y  Lb_ENDVERTEX_Z  L_ENDVERTEX_X  \
# Rec_key
# 0              0.952388       -0.165336       26.651770     402.777832
# 1              0.845292       -0.195122        3.622388     139.395874
# 2             -0.480003       -0.762014       18.670696    -819.340149
# 3              1.681797       -2.255294      -36.569271     113.645294
# 4              0.824895       -0.252737       74.871048    -100.702072
# ...                 ...             ...             ...            ...
# 366391         0.964920        0.161698      -12.157676     293.129822
# 366392        -0.498788        1.215896       21.856564    -176.847626
# 366393         0.114458       -0.046962       25.276293     -29.465662
# 366394         1.096764       -0.076485      -13.951857      42.977512
# 366395         1.382697        0.157468       79.494102     482.254425
#
#          L_ENDVERTEX_Y  L_ENDVERTEX_Z  Jpsi_ENDVERTEX_X  Jpsi_ENDVERTEX_Y  \
# Rec_key
# 0          -229.470520    5536.814453            0.9524           -0.1653
# 1           322.585419    7428.522461            0.8453           -0.1950
# 2          -626.124390    5389.564453           -0.4801           -0.7620
# 3          -329.222229    4678.392090            1.6818           -2.2553
# 4            60.565861    6466.218750            0.8242           -0.2542
# ...                ...            ...               ...               ...
# 366391       39.016293    7097.797363            0.9649            0.1621
# 366392      145.914993    8691.596680           -0.5001            1.2166
# 366393      -15.364128     949.110657            0.1145           -0.0469
# 366394     -134.660324    4807.495117            1.0967           -0.0764
# 366395     -270.556763    6824.267578            1.3827            0.1575
#
#          Jpsi_ENDVERTEX_Z         L_PX  ...  DTF_FixJPsiLambda_PIDSubs_p_PY  \
# Rec_key                                 ...
# 0               26.652201  1910.136719  ...                     -186.566345
# 1                3.620400   481.652618  ...                      222.666214
# 2               18.671101 -5395.257812  ...                     -323.442810
# 3              -36.569199  7835.708984  ...                    -1702.511353
# 4               74.883598   -74.406654  ...                      135.662018
# ...                   ...          ...  ...                             ...
# 366391         -12.151800  3175.616943  ...                      -18.306223
# 366392          21.869101 -2664.720215  ...                      -50.586430
# 366393          25.275400 -6107.898926  ...                     -133.646973
# 366394         -13.952700  -279.406677  ...                      -92.683861
# 366395          79.494202  3857.519287  ...                      -79.852051
#
#          DTF_FixJPsiLambda_PIDSubs_p_PZ  DTF_FixJPsiLambda_PIDSubs_mum_PX  \
# Rec_key
# 0                           5411.963379                       -804.469727
# 1                           4137.976074                       -605.608093
# 2                           2628.927246                          4.108163
# 3                          24506.517578                       8712.822266
# 4                           8106.856445                      -3448.149902
# ...                                 ...                               ...
# 366391                      7767.518555                       1504.345581
# 366392                     -2812.631592                      -3547.666504
# 366393                     15975.192383                      -3526.683594
# 366394                      3969.945801                       1982.495117
# 366395                      1969.780762                       2975.557617
#
#          DTF_FixJPsiLambda_PIDSubs_mum_PY  DTF_FixJPsiLambda_PIDSubs_mum_PZ  \
# Rec_key
# 0                             -535.944397                      22858.960938
# 1                              594.454895                      11170.495117
# 2                             -790.314697                       5651.807129
# 3                           -18033.572266                     231397.500000
# 4                            -1045.294434                      90591.554688
# ...                                   ...                               ...
# 366391                         715.472656                      49351.718750
# 366392                        1885.741577                      33505.289062
# 366393                        -343.335175                      44636.988281
# 366394                       -2486.259033                      26074.431641
# 366395                       -1001.848267                      23227.001953
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PX  DTF_FixJPsiLambda_PIDSubs_mup_PY  \
# Rec_key
# 0                             1438.071777                       1619.347290
# 1                               71.893692                      -2873.631348
# 2                            -5579.078613                       -431.151581
# 3                              336.531647                      -3496.248779
# 4                              588.637329                        239.301941
# ...                                   ...                               ...
# 366391                        -112.221489                       2933.706299
# 366392                       -1337.816284                       1466.083374
# 366393                       -3534.635254                      -3121.734619
# 366394                        2165.314453                        -46.072693
# 366395                        6022.983887                       2011.241821
#
#          DTF_FixJPsiLambda_PIDSubs_mup_PZ  TrackType   MC_key
# Rec_key
# 0                            23634.302734          T        0
# 1                            73489.484375          T       29
# 2                            23151.667969          T       69
# 3                            45100.238281          T      119
# 4                            10912.332031          T       -1
# ...                                   ...        ...      ...
# 366391                       37641.914062          T  8921673
# 366392                       45027.328125          T  8921702
# 366393                       91762.195312          T  8921772
# 366394                       39433.843750          T  8921784
# 366395                       61724.515625          T  8921805
#
# [366396 rows x 154 columns]

# %% [markdown]
# # Istogrammi

# %%
plt.hist(df['L_ENDVERTEX_Z'], bins=100, range=(0, 1e4))
plt.xlabel('z', loc='right')
plt.ylabel('Events', loc='top')
plt.show()

# %%
show_titles = False

# %%
fig, ax = plt.subplots()
ax.hist(df['L_ENDVERTEX_Z'], bins=100, range=(0, 1e4))
ax.set_xlabel('z')
ax.set_ylabel('Events', loc='top')

if show_titles:
    ax.set_title("My plot")
    
ax.ticklabel_format(axis='x', style='sci', scilimits=(0,0), useMathText=True)

plt.show()

# %%
lpz_low = df['L_PZ'] <= 2e4
lpz_mid = (2e4 < df['L_PZ']) & (df['L_PZ'] <= 8e4)
lpz_high = df['L_PZ'] > 8e4

# %%
common_plot_params = {
    'density': True,
    'alpha': 0.6,
    'range': (0, 1e4),
    'bins': 100
}

fig, ax = plt.subplots()

ax.hist(df.loc[lpz_low, 'L_ENDVERTEX_Z'], **common_plot_params, color='tab:blue')
ax.hist(df.loc[lpz_mid, 'L_ENDVERTEX_Z'], **common_plot_params, color='tab:orange')
ax.hist(df.loc[lpz_high, 'L_ENDVERTEX_Z'], **common_plot_params, color='mediumseagreen')

plt.show()

# %%
common_plot_params = {
    'density': True,
#    'alpha': 0.6,
    'range': (0, 1e4),
    'bins': 100,
    'histtype': 'step'
}

fig, ax = plt.subplots()

ax.hist(df.loc[lpz_low, 'L_ENDVERTEX_Z'], **common_plot_params, color='tab:blue')
ax.hist(df.loc[lpz_mid, 'L_ENDVERTEX_Z'], **common_plot_params, color='tab:orange')
ax.hist(df.loc[lpz_high, 'L_ENDVERTEX_Z'], **common_plot_params, color='mediumseagreen')

plt.show()

# %%
from matplotlib import colors as mcols

# %%
mask_to_label = {
    'low': 'Low',
    'mid': 'Mid'
}

# %%
common_plot_params = {
    'density': True,
#    'alpha': 0.6,
    'range': (0, 1e4),
    'bins': 100,
    'histtype': 'stepfilled'
}

fig, ax = plt.subplots()

ax.hist(df.loc[lpz_low, 'L_ENDVERTEX_Z'], label='Low', color=mcols.to_rgba('tab:blue', 0.2), edgecolor='tab:blue', **common_plot_params)
ax.hist(df.loc[lpz_mid, 'L_ENDVERTEX_Z'], label='Mid', color=mcols.to_rgba('tab:orange', 0.2), edgecolor='tab:orange', **common_plot_params)
ax.hist(df.loc[lpz_high, 'L_ENDVERTEX_Z'], label='High', color=mcols.to_rgba('tab:green', 0.2), edgecolor='tab:green', **common_plot_params)
ax.axvline(2500, label='2500')

ax.legend(frameon=False, loc='upper left')

plt.show()

# %%
common_plot_params = {
    'density': True,
    'range': (0, 1e4),
    'bins': 100,
    'histtype': 'stepfilled',
    'edgecolor': 'k',
    'facecolor': 'none'
}

fig, ax = plt.subplots()

ax.hist(df.loc[lpz_low, 'L_ENDVERTEX_Z'], label='Low', hatch='\\\\', **common_plot_params)
ax.hist(df.loc[lpz_mid, 'L_ENDVERTEX_Z'], label='Mid', hatch='||', **common_plot_params)
#ax.hist(df.loc[lpz_high, 'L_ENDVERTEX_Z'], label='High', color=mcols.to_rgba('tab:green', 0.2), edgecolor='tab:green', **common_plot_params)
#ax.axvline(2500, label='2500')

ax.legend(frameon=False, loc='upper left')

fig.savefig('myplot.png', bbox_inches='tight', dpi=150)

plt.show()

# %% [markdown]
# # Plot

# %%
x = np.linspace(0,100,100)

# %%
def cubic(x):
    return x**3

# %%
y = x**2
z = (x**2)*np.sin(x)
w = cubic(x)

# %%
fig, ax = plt.subplots()

ax.plot(x, y, label='$x^2$', color='k', linestyle='solid')
ax.plot(x, w, label=r'$x^3$', linestyle='dotted', color='k')
ax.grid(linestyle='--')

ax.legend(frameon=False)

plt.show()

# %% [markdown]
# # Scatterplot

# %%
fig, ax = plt.subplots()

ax.scatter(df['L_ENDVERTEX_Z'], df['L_ENDVERTEX_X'])

ax.set_xlim(-3e4, 3e4)
ax.set_ylim(-5e3, 5e3)

ax.set_xlabel('z')
ax.set_ylabel('x')

plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(df['L_ENDVERTEX_Z'], df['L_ENDVERTEX_X'], alpha=.005)

ax.set_xlim(-3e4, 3e4)
ax.set_ylim(-5e3, 5e3)

ax.set_xlabel('z')
ax.set_ylabel('x')

plt.show()

# %%
fig, ax = plt.subplots()

spl = ax.scatter(
    df['L_ENDVERTEX_Z'], df['L_ENDVERTEX_X'],
    c=df['L_PZ'], s=.001, vmin=0, vmax=1e5, cmap='turbo')

ax.set_ylim(-2e3, 2e3)
ax.set_xlim(0, 1e4)

ax.set_xlabel('z')
ax.set_ylabel('x')

cbar = fig.colorbar(spl, label='$p_z$')
cbar.formatter.set_powerlimits((0,0))

plt.show()

# %% [markdown]
# # Hist2d

# %%
fig, ax = plt.subplots()

_, _, _, h2d = ax.hist2d(
    df['L_ENDVERTEX_Z'], df['L_ENDVERTEX_X'], bins=100, range=[[0, 1e4], [-1e3, 1e3]], cmap='turbo')


ax.set_xlabel('z')
ax.set_ylabel('x')

cbar = fig.colorbar(h2d, label='$p_z$')
#cbar.formatter.set_powerlimits((0,0))

plt.show()

# %%
fig, ax = plt.subplots()

df_sampled = df.sample(2000)

_, _, _, h2d = ax.hist2d(
    df_sampled['L_ENDVERTEX_Z'], df_sampled['L_ENDVERTEX_X'], bins=30, range=[[0, 1e4], [-1e3, 1e3]], cmap='turbo')


ax.set_xlabel('z')
ax.set_ylabel('x')

cbar = fig.colorbar(h2d, label='$p_z$')
#cbar.formatter.set_powerlimits((0,0))

plt.show()

# %%
fig, ax = plt.subplots()

_, _, _, h2d = ax.hist2d(
    df['L_ENDVERTEX_Z'], df['L_ENDVERTEX_X'], bins=100, range=[[0, 1e4], [-1e3, 1e3]], cmap='binary_r')


ax.set_xlabel('z')
ax.set_ylabel('x')

cbar = fig.colorbar(h2d, label='$p_z$')
#cbar.formatter.set_powerlimits((0,0))

plt.show()

# %% [markdown]
# # Imshow

# %%
cmat = df[['L_ENDVERTEX_X', 'L_ENDVERTEX_Y', 'L_ENDVERTEX_Z', 'L_PX', 'L_PY', 'L_PZ']].corr()

# %%
cmat
# Out:
#                L_ENDVERTEX_X  L_ENDVERTEX_Y  L_ENDVERTEX_Z      L_PX  \
# L_ENDVERTEX_X       1.000000      -0.019037       0.035492 -0.002925
# L_ENDVERTEX_Y      -0.019037       1.000000      -0.097703  0.007747
# L_ENDVERTEX_Z       0.035492      -0.097703       1.000000  0.001264
# L_PX               -0.002925       0.007747       0.001264  1.000000
# L_PY               -0.000444       0.003002      -0.001916 -0.085874
# L_PZ               -0.000243      -0.001830       0.002446  0.142183
#
#                    L_PY      L_PZ
# L_ENDVERTEX_X -0.000444 -0.000243
# L_ENDVERTEX_Y  0.003002 -0.001830
# L_ENDVERTEX_Z -0.001916  0.002446
# L_PX          -0.085874  0.142183
# L_PY           1.000000  0.163908
# L_PZ           0.163908  1.000000

# %%
fig, ax = plt.subplots()

ims = ax.imshow(cmat, cmap='Spectral_r')
ims.set_clim(-0.2,0.2)

ax.set_xticks(np.arange(6))
ax.set_xticklabels(cmat.columns, rotation=90)

ax.set_yticks(np.arange(6))
ax.set_yticklabels(cmat.columns)

for i in range(len(cmat)):
    for j in range(len(cmat)):
        if i==j:
            color = 'w'
        else:
            color = 'k'
                   
        ax.text(i, j, "{0:.2f}".format(cmat.iloc[i,j]), ha='center', va='center', color=color)

fig.colorbar(ims)

plt.show()

# %%
def func2d(x, y):
    return np.cos(x) + np.sin(y)

# %%
xs = np.linspace(-5, 5, 1000)
ys = np.linspace(-10, 10, 1000)

xgrid, ygrid = np.meshgrid(xs, ys)
zs = func2d(xgrid, ygrid)

# %%
fig, ax = plt.subplots()

ims = ax.imshow(zs, extent=[-5, 5, -10, 10], aspect='auto', cmap='Spectral_r')

fig.colorbar(ims)

plt.show()

# %%
fig, ax = plt.subplots()

ims = ax.imshow(zs, extent=[-5, 5, -10, 10], aspect='auto', cmap='binary')

fig.colorbar(ims)

plt.show()

# %%
fig, ax = plt.subplots()

cnt = ax.contour(zs, cmap='binary')
ax.clabel(cnt)

plt.show()

# %% [markdown]
# # Subplots

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 7))
fig.suptitle('General title', fontsize=24)

ax = axs[0, 0]
_, _, _, h2d = ax.hist2d(
    df['L_ENDVERTEX_Z'], df['L_ENDVERTEX_X'], bins=100, range=[[0, 1e4], [-1e3, 1e3]], cmap='turbo')


ax.set_xlabel('z')
ax.set_ylabel('x')

cbar = fig.colorbar(h2d, label='$p_z$', ax=ax)
ax.set_title('First plot')
#cbar.formatter.set_powerlimits((0,0))


plt.show()

# %% [markdown]
# # Twinx

# %%
common_plot_params = {
    'density': False,
    'range': (0, 1e4),
    'bins': 100,
    'histtype': 'stepfilled'
}

fig, ax1 = plt.subplots()

ax1.hist(df.loc[lpz_low, 'L_ENDVERTEX_Z'], label='Low', color=mcols.to_rgba('tab:blue', 0.2), edgecolor='tab:blue', **common_plot_params)

ax1.set_ylabel('Events (low)', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()

ax2.set_ylabel('Events (mid)', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

ax2.hist(df.loc[lpz_mid, 'L_ENDVERTEX_Z'], label='Mid', color=mcols.to_rgba('tab:orange', 0.2), edgecolor='tab:orange', **common_plot_params)

#ax.legend(frameon=False, loc='upper left')

#ax1.legend()
#ax2.legend(loc='center right')

plt.show()

# %% [markdown]
# # Plotting a fit in Python

# %%
data = np.random.normal(0, 1, size=int(1e4))

# %%
n, bins, _ = plt.hist(data, bins=80)
plt.close()

# %%
len(n)
# Out:
# 80

# %%
len(bins)
# Out:
# 81

# %%
bins
# Out:
# array([-3.38349563, -3.29216026, -3.20082489, -3.10948952, -3.01815414,
#        -2.92681877, -2.8354834 , -2.74414803, -2.65281266, -2.56147729,
#        -2.47014191, -2.37880654, -2.28747117, -2.1961358 , -2.10480043,
#        -2.01346506, -1.92212968, -1.83079431, -1.73945894, -1.64812357,
#        -1.5567882 , -1.46545283, -1.37411745, -1.28278208, -1.19144671,
#        -1.10011134, -1.00877597, -0.9174406 , -0.82610522, -0.73476985,
#        -0.64343448, -0.55209911, -0.46076374, -0.36942837, -0.27809299,
#        -0.18675762, -0.09542225, -0.00408688,  0.08724849,  0.17858386,
#         0.26991924,  0.36125461,  0.45258998,  0.54392535,  0.63526072,
#         0.72659609,  0.81793146,  0.90926684,  1.00060221,  1.09193758,
#         1.18327295,  1.27460832,  1.36594369,  1.45727907,  1.54861444,
#         1.63994981,  1.73128518,  1.82262055,  1.91395592,  2.0052913 ,
#         2.09662667,  2.18796204,  2.27929741,  2.37063278,  2.46196815,
#         2.55330353,  2.6446389 ,  2.73597427,  2.82730964,  2.91864501,
#         3.00998038,  3.10131576,  3.19265113,  3.2839865 ,  3.37532187,
#         3.46665724,  3.55799261,  3.64932799,  3.74066336,  3.83199873,
#         3.9233341 ])

# %%
bins[:-1]
# Out:
# array([-3.38349563, -3.29216026, -3.20082489, -3.10948952, -3.01815414,
#        -2.92681877, -2.8354834 , -2.74414803, -2.65281266, -2.56147729,
#        -2.47014191, -2.37880654, -2.28747117, -2.1961358 , -2.10480043,
#        -2.01346506, -1.92212968, -1.83079431, -1.73945894, -1.64812357,
#        -1.5567882 , -1.46545283, -1.37411745, -1.28278208, -1.19144671,
#        -1.10011134, -1.00877597, -0.9174406 , -0.82610522, -0.73476985,
#        -0.64343448, -0.55209911, -0.46076374, -0.36942837, -0.27809299,
#        -0.18675762, -0.09542225, -0.00408688,  0.08724849,  0.17858386,
#         0.26991924,  0.36125461,  0.45258998,  0.54392535,  0.63526072,
#         0.72659609,  0.81793146,  0.90926684,  1.00060221,  1.09193758,
#         1.18327295,  1.27460832,  1.36594369,  1.45727907,  1.54861444,
#         1.63994981,  1.73128518,  1.82262055,  1.91395592,  2.0052913 ,
#         2.09662667,  2.18796204,  2.27929741,  2.37063278,  2.46196815,
#         2.55330353,  2.6446389 ,  2.73597427,  2.82730964,  2.91864501,
#         3.00998038,  3.10131576,  3.19265113,  3.2839865 ,  3.37532187,
#         3.46665724,  3.55799261,  3.64932799,  3.74066336,  3.83199873])

# %%
midpoints = (bins[1:] + bins[:-1])/2

# %%
def gaussian(x, mu, sigma):
    return 1/np.sqrt(2*np.pi) * np.exp(-0.5 * (x-mu)**2 / sigma**2)

# %%
fig, axs = plt.subplots(2, 1, sharex=True, figsize=(5,6), gridspec_kw={'height_ratios': [3, 1]})
fig.subplots_adjust(hspace=0)

ax = axs[0]

ax.errorbar(midpoints, n, np.sqrt(n), linestyle='', marker='.', ecolor='k', capsize=2, label='Data')
ax.plot(midpoints, 900*gaussian(midpoints,0, 1), label='Fit')

ax.legend(frameon=False)
ax.set_ylabel('Events')

ax = axs[1]

ax.errorbar(midpoints, (n - 900*gaussian(midpoints, 0, 1))/np.sqrt(n), 1., linestyle='', marker='.')
ax.set_ylim(-3, 3)
ax.grid(linestyle='--')
ax.axhline(0, color='tab:orange')

plt.show()
# Out:
# /tmp/ipykernel_22490/4240775805.py:14: RuntimeWarning: divide by zero encountered in true_divide
#   ax.errorbar(midpoints, (n - 900*gaussian(midpoints, 0, 1))/np.sqrt(n), 1., linestyle='', marker='.')

# %%
#scipy.curve_fit()

# %%
fig, axs = plt.subplots(2, 1, sharex=True, figsize=(5,6), gridspec_kw={'height_ratios': [3, 1]})
fig.subplots_adjust(hspace=0)

ax = axs[0]

ax.errorbar(midpoints, n, np.sqrt(n), linestyle='', marker='.', ecolor='k', capsize=2, label='Data')
ax.plot(midpoints, 900*gaussian(midpoints,0, 1), label='Fit')

ax.legend(frameon=False)
ax.set_ylabel('Events')

ax = axs[1]

ax.bar(x=midpoints, height=(n - 900*gaussian(midpoints, 0, 1))/np.sqrt(n), width=.04, color='tab:gray')
ax.set_ylim(-3, 3)
ax.grid(linestyle='--')
ax.axhline(0, color='tab:orange')

plt.show()
# Out:
# /tmp/ipykernel_22490/3330899988.py:14: RuntimeWarning: divide by zero encountered in true_divide
#   ax.bar(x=midpoints, height=(n - 900*gaussian(midpoints, 0, 1))/np.sqrt(n), width=.04, color='tab:gray')

# %%
with plt.xkcd():
    fig, ax = plt.subplots()
    ax.hist(df['L_ENDVERTEX_Z'], bins=100, range=(0,1e4))
    ax.set_title("Zec's best plot")
    plt.show()
# Out:
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
